# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Content-Type': 'application/json;charset=utf-8',
    'Origin': 'https://yearbook.sntiitk.in',
    'Connection': 'keep-alive',
    'Referer': 'https://yearbook.sntiitk.in/',
}

data = '{"roll":"170713","_id":"60a55f77819323d199d485de","visibility":true,"apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"gusoumya"}'

response = requests.post('https://yearbook.sntiitk.in/updateComment', headers=headers, data=data)

# %%
response.content
# Out:
# b'{"remark":"Later Sucker"}'

# %%
len("911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4")
# Out:
# 64

# %%
"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4".decode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-ee386724df68> in <module>
# ----> 1 "911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4".decode()
#
# AttributeError: 'str' object has no attribute 'decode'
