# %% [markdown]
# # Downloading by getUser (they stopped the false return on this)

# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Content-Type': 'application/json;charset=utf-8',
    'Origin': 'https://yearbook.sntiitk.in',
    'Connection': 'keep-alive',
    'Referer': 'https://yearbook.sntiitk.in/',
}

data_base = '{"roll":"170191","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}'

# %%
def convert_string(roll_no, original = '{"roll":"170191","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}'):
    new_data = original[:9]
    new_data += "{}".format(roll_no)
    new_data += original[15:]
    return new_data

import time, numpy as np
# for roll_no in range(170001, 170840):
for roll_no in range(170176, 170840):
    print("Working for roll number:", roll_no)
    new_data = convert_string(roll_no)
    response = requests.post('https://yearbook.sntiitk.in/getUser', headers=headers, data=new_data)
    with open("/media/ayush/DATA/Codes/yearbook/data_raw/{}.txt".format(roll_no),"w+") as f:
        f.write(str(response.content))
    print("Recieved: -------> ", str(response.content)[:10])
    if(response.content == {}):
        break
    print("Finished for roll no: ", roll_no)
    timer_interval = int(np.random.uniform(low=2, high=10))
    print("Waiting for: ", timer_interval, " secs")
    print("------------------------------")
    time.sleep(timer_interval)
# Out:
# Working for roll number: 170176
# Recieved: ------->  b'[{"pic":
# Finished for roll no:  170176
# Waiting for:  4  secs
# ------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4ec94d807f7c> in <module>
#      20     print("Waiting for: ", timer_interval, " secs")
#      21     print("------------------------------")
# ---> 22     time.sleep(timer_interval)
#
# KeyboardInterrupt:

# %% [markdown]
# # Downloading using userByEmail

# %%
print("hi")
# Out:
# hi

# %%
import pickle 

dump_emailsF = open("/media/ayush/DATA/Codes/yearbook/data_emails.pkl", "rb")
emailIds = pickle.load(dump_emailsF)
print(emailIds)
# Out:
# {'170001': 'aaishiashirbad@gmail.com', '170002': 'ubbabrise@gmail.com', '170003': 'aakarsh2299@gmail.com', '170004': 'aakashkhandelwal3021@gmail.com', '170006': 'aamir.makki@gmail.com', '170009': 'ayush26saini@gmail.com', '170010': 'aayusharma27@gmail.com', '170011': 'abhatamrakar2016@gmail.com', '170013': 'abhayvar123@gmail.com', '170014': 'abhijaatk@gmail.com', '170015': 'abhijeetnirmal007@gmail.com', '170017': 'abiiankit@gmail.com', '170018': 'abhinavbende619@gmail.com', '170021': 'abhishekanand6527@gmail.com', '170022': 'abhishekbhatia84@gmail.com', '170023': 'gup.abhi1998@gmail.com', '170024': 'abhishek.gupta748839@gmail.com', '170026': 'ak3605424@gmail.com', '170027': 'amaddheshiya44@gmail.com', '170031': 'abhi291099@gmail.com', '170033': 'abhisheksinghtindal@gmail.com', '170034': 'abhi5august@gmail.com', '170036': 'abhishake.yadav.iitk@gmail.com', '170039': 'pandey.abhyuday07@gmail.com', '170041': 'achyutverma9@gmail.com', '170042': 'adesh00719@gmail.com', '170044': 'adityamoo
# ...

# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:88.0) Gecko/20100101 Firefox/88.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Content-Type': 'application/json;charset=utf-8',
    'Origin': 'https://yearbook.sntiitk.in',
    'Connection': 'keep-alive',
    'Referer': 'https://yearbook.sntiitk.in/',
}

data = '{"email":"yugesh.kothari@gmail.com","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}'

# %%
def convert_string(email, original = '{"email":"","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}'):
    new_data = original[:10]
    new_data += "{}".format(email)
    new_data += original[10:]
    return new_data

print(convert_string("7ayushgupta@gmail.com"))
print(convert_string("adi.1129311@gmail.com"))
# Out:
# {"email":"7ayushgupta@gmail.com","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}
# {"email":"adi.1129311@gmail.com","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}

# %%
import time, numpy as np
for roll_no in range(170001, 170840):
    print("Working for roll number:", roll_no)
    if str(roll_no) in emailIds.keys():
        email_ = emailIds[str(roll_no)]
        print(roll_no, email_)
    else:
        print("Not available for this")
        continue
    new_data = convert_string(email_)
    print(new_data)
    response = requests.post('https://yearbook.sntiitk.in/userByEmail', headers=headers, data=new_data)
    with open("/media/ayush/DATA/Codes/yearbook/data_raw/{}.txt".format(roll_no),"w+") as f:
        f.write(str(response.content))
    print("Recieved: -------> ", str(response.content)[:10])
    print("Finished for roll no: ", roll_no)
    timer_interval = int(np.random.uniform(low=1, high=2))
    timer_interval=0
    print("Waiting for: ", timer_interval, " secs")
    print("------------------------------")
    time.sleep(timer_interval)
# Out:
# Working for roll number: 170001
# 170001 aaishiashirbad@gmail.com
# {"email":"aaishiashirbad@gmail.com","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}
# Recieved: ------->  b'[{"pic":
# Finished for roll no:  170001
# Waiting for:  0  secs
# ------------------------------
# Working for roll number: 170002
# 170002 ubbabrise@gmail.com
# {"email":"ubbabrise@gmail.com","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}
# Recieved: ------->  b'[{"pic":
# Finished for roll no:  170002
# Waiting for:  0  secs
# ------------------------------
# Working for roll number: 170003
# 170003 aakarsh2299@gmail.com
# {"email":"aakarsh2299@gmail.com","apiKey":"911d6e9f27ba348fd6b0c48adaad5dbfaa5d2069954a2b235df1c5dcf35004c4","username":"7ayushgupta"}
# Recieved: ------->  b'[{"pic":
# Finished for roll no:  170003
# Waiting for:  0  secs
# ------------------------------
# ...
